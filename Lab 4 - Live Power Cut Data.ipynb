# %% [markdown]
# ### Lab 4 - Live Power Cut Data

# %%
from IPython.display import display
import urllib3
import json
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
import seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = [15,10]

# %% [markdown]
# This Jupyter notebook provides an example of what you can do using data published on NGED's connected data portal. This specific Lab will walk you through extracting real time power cut data through API calls and visualising them using Python.

# %% [markdown]
# ### Loading Live Power Cut Data
#
# NGED's connected data portal is a rich and diverse repository of datasets that is constantly growing and evolving. One of the key benefits of the portal is that it enables API requests. One of the datasets we will be utilising for this lab is the live power cut data.

# %%
# Create a PoolManager instance for sending requests.
http = urllib3.PoolManager()

# This is the dataset url
url = 'https://connecteddata.nationalgrid.co.uk/api/3/action/datastore_search?resource_id=292f788f-4339-455b-8cc0-153e14509d4d&limit=300000'  

# Calls the endpoint
response = http.request('GET',url)

# Use the json module to load CKAN's response into a dictionary.
response_dict = json.loads(response.data)

# Display the first record  in the response
display(response_dict['result']['records'][0])
# Out:
# {'_id': 1,
#  'Upload Date': '2022-12-12T10:41:00',
#  'Region': 'South West',
#  'Incident ID': 'INCD-16943-v',
#  'Confirmed Off': 0,
#  'Predicted Off': 2,
#  'Restored': 0,
#  'Status': 'Awaiting',
#  'Planned': 'false',
#  'Category': 'LV GENERIC',
#  'Resource Status': 'COMP',
#  'Start Time': '2022-12-12T08:43:00',
#  'ETR': '2022-12-12T12:00:00',
#  'Voltage': 'LV',
#  'Location Latitude': 50.60938,
#  'Location Longitude': -3.690687,
#  'Postcodes': 'TQ13 9NH'}

# %%
# Construct DataFrame from a dictionary
df = pd.DataFrame(response_dict['result']['records'])

# Set the index to _id 
df.set_index(['_id'],inplace=True)

# Set datetime column

df['Start Time'] = pd.to_datetime(df['Start Time'])

# Display the dataframe
display(df)
# Out:
#              Upload Date         Region   Incident ID  Confirmed Off  \
# _id
# 1    2022-12-12T10:41:00     South West  INCD-16943-v              0
# 2    2022-12-12T10:41:00     South West  INCD-39513-q              0
# 3    2022-12-12T10:41:00     South West  INCD-39515-q            110
# 4    2022-12-12T10:41:00    South Wales   INCD-3795-t              0
# 5    2022-12-12T10:41:00    South Wales  INCD-24511-g             15
# 6    2022-12-12T10:41:00    South Wales  INCD-24513-g              0
# 7    2022-12-12T10:41:00  West Midlands  INCD-29629-b              0
# 8    2022-12-12T10:41:00  West Midlands  INCD-41072-c              0
# 9    2022-12-12T10:41:00  West Midlands  INCD-29631-b              0
# 10   2022-12-12T10:41:00  West Midlands  INCD-41067-c              0
# 11   2022-12-12T10:41:00  West Midlands  INCD-41071-c              0
# 12   2022-12-12T10:41:00  West Midlands  INCD-41054-c              2
# 13   2022-12-12T10:41:00  East Midlands  INCD-50549-m              0
# 14   2022-12-12T10:41:00  East Midlands  INCD-50552-m              1
# 15   2022-12-12T10:41:00  East Midlands  INCD-27054-q             13
# 16   2022-12-12T10:41:00  East Midlands  INCD-50555-m              0
# 17   2022-12-12T10:41:00  East Midlands  INCD-50546-m             33
# 18   2022-12-12T10:41:00  East Midlands  INCD-27060-q              0
# 19   2022-12-12T10:41:00  East Midlands  INCD-50543-m             26
# 20   2022-12-12T10:41:00  East Midlands  INCD-50545-m              0
# 21   2022-12-12T10:41:00  East Midlands  INCD-50547-m              0
# 22   2022-12-12T10:41:00  East Midlands  INCD-50486-m              1
# 23   2022-12-12T10:41:00  East Midlands  INCD-27063-q            123
#
#      Predicted Off  Restored       Status Planned        Category  \
# _id
# 1                2         0     Awaiting   false      LV GENERIC
# 2                1         2  In Progress   false      LV GENERIC
# 3                0      1772  In Progress   false      HV GENERIC
# 4                3         0  In Progress   false      LV GENERIC
# 5               49         0  In Progress   false      LV GENERIC
# 6               20         0  In Progress   false      LV GENERIC
# 7               10         0  In Progress   false  LV UNDERGROUND
# 8               59         0  In Progress   false         LV FUSE
# 9               34         0  In Progress   false      LV GENERIC
# 10              27         0  In Progress   false         LV FUSE
# 11               9         0  In Progress   false         LV FUSE
# 12               0         0  In Progress   false  HV UNDERGROUND
# 13               9         0  In Progress   false         LV FUSE
# 14               0         0     Awaiting   false        HV PLANT
# 15               5         0  In Progress   false  LV UNDERGROUND
# 16              38         0     Awaiting   false         LV FUSE
# 17              64         0  In Progress   false  LV UNDERGROUND
# 18              14         0  In Progress   false         LV FUSE
# 19               0         0  In Progress   false  LV UNDERGROUND
# 20              40         0  In Progress   false  LV UNDERGROUND
# 21              43         0  In Progress   false      LV GENERIC
# 22               0         0  In Progress   false      HV GENERIC
# 23               0         0  In Progress   false    HV ISOLATION
#
#     Resource Status          Start Time                  ETR Voltage  \
# _id
# 1              COMP 2022-12-12 08:43:00  2022-12-12T12:00:00      LV
# 2               ONS 2022-12-12 07:38:00  2022-12-12T11:00:00      LV
# 3               ONS 2022-12-12 09:27:00  2022-12-12T11:30:00      HV
# 4               ONS 2022-12-12 08:22:00  2022-12-12T11:30:00      LV
# 5               ONS 2022-12-12 05:31:00  2022-12-12T13:00:00      LV
# 6              LEFS 2022-12-12 06:59:00  2022-12-12T14:00:00      LV
# 7               ONS 2022-12-12 08:48:00                 None      LV
# 8              DISP 2022-12-12 09:44:00  2022-12-12T12:00:00      LV
# 9              DISP 2022-12-12 10:02:00  2022-12-12T16:30:00      LV
# 10             DISP 2022-12-12 09:17:00  2022-12-12T11:30:00      LV
# 11             DISP 2022-12-12 09:31:00  2022-12-12T12:00:00      LV
# 12             COMP 2022-12-12 06:54:00                 None      HV
# 13              ONS 2022-12-12 07:57:00  2022-12-12T14:00:00      LV
# 14             ASSN 2022-12-12 08:55:00  2022-12-12T15:00:00      HV
# 15              ONS 2022-12-12 08:11:00  2022-12-12T12:30:00      LV
# 16             ACPT 2022-12-12 09:04:00  2022-12-12T12:00:00      LV
# 17              ONS 2022-12-12 07:23:00  2022-12-12T15:00:00      LV
# 18              ONS 2022-12-12 09:29:00  2022-12-12T13:30:00      LV
# 19             COMP 2022-12-12 07:05:00  2022-12-12T13:30:00      LV
# 20              ONS 2022-12-12 07:08:00  2022-12-12T15:00:00      LV
# 21             DISP 2022-12-12 07:54:00  2022-12-12T12:30:00      LV
# 22             COMP 2022-12-10 03:41:00                 None      HV
# 23             DISP 2022-12-12 10:01:00  2022-12-12T13:00:00      HV
#
#      Location Latitude  Location Longitude  \
# _id
# 1             50.60938           -3.690687
# 2             50.72438           -3.532782
# 3             51.06759           -4.053455
# 4             51.69906           -2.684208
# 5             51.51291           -3.425934
# 6             51.43342           -3.189655
# 7             53.10632           -2.027683
# 8             52.43684           -1.917552
# 9             52.67558           -2.780715
# 10            52.58611           -2.126993
# 11            52.52697           -1.924695
# 12            52.53401           -2.086095
# 13            52.97014           -1.317750
# 14            53.17908           -1.227237
# 15            52.59684           -1.073435
# 16            51.94326           -0.881465
# 17            52.22419           -0.911577
# 18            52.62727           -1.127131
# 19            52.41911           -1.509480
# 20            52.26705           -0.861275
# 21            53.10480           -1.269555
# 22            52.47020           -1.546569
# 23            52.68336           -0.163960
#
#                                              Postcodes
# _id
# 1                                             TQ13 9NH
# 2                                              EX4 3SH
# 3    EX32 0PA, EX32 0NZ, EX32 0ND, EX32 0LZ, EX32 0...
# 4                                             NP16 6SX
# 5                         CF72 9HZ, CF72 9HY, CF72 9HN
# 6                                   CF64 3NE, CF64 3NJ
# 7                         ST13 5ES, ST13 6AB, ST13 5DQ
# 8    B29 7PX, B29 7RP, B29 7PH, B30 2YH, B29 7PQ, B...
# 9                   SY3 0LD, SY3 0LE, SY3 0JU, SY3 0JX
# 10         WV1 1DG, WV1 1HN, WV1 1TY, WV1 1TS, WV1 1EA
# 11                                    B42 1DU, B42 1DF
# 12                                   DY4 9AQ, WV14 9EE
# 13                                    DE7 5GJ, DE7 5GH
# 14                                            NG19 8RL
# 15                                             LE2 4LG
# 16    MK18 3DG, MK18 3DQ, MK18 3HD, MK18 3JG, MK18 3DH
# 17   NN4 8RL, NN4 8RD, NN4 8RE, NN4 8RB, NN4 8RJ, N...
# 18   LE1 6WT, LE1 6XL, LE1 6TR, LE1 6XP, LE1 7AX, L...
# 19                                             CV1 4ER
# 20                           NN3 6NS, NN3 6FF, NN3 6FE
# 21   NG17 8JJ, NG17 8GU, NG17 8GW, NG17 8GY, NG17 8...
# 22                                             CV7 8NR
# 23   PE6 0NF, PE12 0UB, PE6 0JX, PE6 0NQ, PE6 0JR, ...

# %%
#flatten postcode lists

all_postcodes = []
for fault in df['Postcodes'].values:
    for pc in (fault.split(',')):
        all_postcodes.append(pc.lstrip())
        
display(all_postcodes)
# Out:
# ['TQ13 9NH',
#  'EX4 3SH',
#  'EX32 0PA',
#  'EX32 0NZ',
#  'EX32 0ND',
#  'EX32 0LZ',
#  'EX32 0PB',
#  'EX32 0NB',
#  'EX32 0NA',
#  'NP16 6SX',
#  'CF72 9HZ',
#  'CF72 9HY',
#  'CF72 9HN',
#  'CF64 3NE',
#  'CF64 3NJ',
#  'ST13 5ES',
#  'ST13 6AB',
#  'ST13 5DQ',
#  'B29 7PX',
#  'B29 7RP',
#  'B29 7PH',
#  'B30 2YH',
#  'B29 7PQ',
#  'B30 2YJ',
#  'B5 7RL',
#  'B29 7PS',
#  'SY3 0LD',
#  'SY3 0LE',
#  'SY3 0JU',
#  'SY3 0JX',
#  'WV1 1DG',
#  'WV1 1HN',
#  'WV1 1TY',
#  'WV1 1TS',
#  'WV1 1EA',
#  'B42 1DU',
#  'B42 1DF',
#  'DY4 9AQ',
#  'WV14 9EE',
#  'DE7 5GJ',
#  'DE7 5GH',
#  'NG19 8RL',
#  'LE2 4LG',
#  'MK18 3DG',
#  'MK18 3DQ',
#  'MK18 3HD',
#  'MK18 3JG',
#  'MK18 3DH',
#  'NN4 8RL',
#  'NN4 8RD',
#  'NN4 8RE',
#  'NN4 8RB',
#  'NN4 8RJ',
#  'NN4 8RG',
#  'NN4 8RH',
#  'LE1 6WT',
#  'LE1 6XL',
#  'LE1 6TR',
#  'LE1 6XP',
#  'LE1 7AX',
#  'LE1 6RL',
#  'LE1 7AS',
#  'CV1 4ER',
#  'NN3 6NS',
#  'NN3 6FF',
#  'NN3 6FE',
#  'NG17 8JJ',
#  'NG17 8GU',
#  'NG17 8GW',
#  'NG17 8GY',
#  'NG17 8GX',
#  'NG17 8GZ',
#  'CV7 8NR',
#  'PE6 0NF',
#  'PE12 0UB',
#  'PE6 0JX',
#  'PE6 0NQ',
#  'PE6 0JR',
#  'PE6 0JW',
#  'PE6 0JT',
#  'PE11 3DZ',
#  'PE11 3ED',
#  'PE6 0NG',
#  'PE6 0JU',
#  'PE6 0LT',
#  'PE11 3DY',
#  'PE6 0NB',
#  'PE6 0LX',
#  'PE12 0UA',
#  'PE6 0JL',
#  'PE11 3BD',
#  'PE11 3EB',
#  'PE6 0JE',
#  'PE6 0NE',
#  'PE6 0LZ',
#  'PE11 3EA',
#  'PE11 3BB',
#  'PE6 0LR',
#  'PE12 6AW',
#  'PE6 0LU',
#  'PE6 0JP']
